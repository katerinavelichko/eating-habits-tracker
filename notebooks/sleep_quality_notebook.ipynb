# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

from plotly.subplots import make_subplots
import plotly.express as px

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # Достанем данные

# %%
data = pd.read_csv('../data/per_statistica.csv') #данные, которые мы нашли
data
# Out:
#      SEX  How many times do you eat a day?  \
# 0      M                                 5
# 1      M                                 6
# 2      F                                 3
# 3      F                                 4
# 4      M                                 5
# ...   ..                               ...
# 2016   F                                 4
# 2017   F                                 5
# 2018   M                                 3
# 2019   F                                 6
# 2020   M                                 5
#
#       How many liters of water do you drink per day?  \
# 0                                                  2
# 1                                                  3
# 2                                                  1
# 3                                                  2
# 4                                                  1
# ...                                              ...
# 2016                                               3
# 2017                                               2
# 2018                                               1
# 2019                                               0
# 2020                                               3
#
#       How many times do you consume alcoholic beverages in a week?  \
# 0                                                     1
# 1                                                     1
# 2                                                     3
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 2016                                                  1
# 2017                                                  0
# 2018                                                  2
# 2019                                                  1
# 2020                                                  0
#
#       How many sugary drinks do you consume per day? Cow's milk  \
# 0                                                  1        Yes
# 1                                                  1        Yes
# 2                                                  3         NO
# 3                                                  1        Yes
# 4                                                  3         NO
# ...                                              ...        ...
# 2016                                               1  Sometimes
# 2017                                               0        Yes
# 2018                                               0        Yes
# 2019                                               1        Yes
# 2020                                               2         NO
#
#      Vegetable drinks (eg soy milk) Low-fat white yogurt Fresh cheeses Meat  \
# 0                               Yes                   NO           Yes  Yes
# 1                               Yes                  Yes           Yes  Yes
# 2                               Yes                   NO     Sometimes  Yes
# 3                               Yes                   NO            NO  Yes
# 4                                NO                   NO            NO  Yes
# ...                             ...                  ...           ...  ...
# 2016                            Yes                  Yes           Yes  Yes
# 2017                             NO                  Yes           Yes  Yes
# 2018                            Yes                  Yes           Yes  Yes
# 2019                             NO                  Yes           Yes  Yes
# 2020                             NO                   NO           Yes  Yes
#
#      Processed Meat (es prosciutto) Fish Eggs Legumes Cooked vegetables  \
# 0                               Yes  Yes  Yes     Yes               Yes
# 1                               Yes  Yes  Yes     Yes               Yes
# 2                               Yes   NO   NO     Yes                NO
# 3                               Yes  Yes  Yes     Yes               Yes
# 4                               Yes  Yes   NO     Yes                NO
# ...                             ...  ...  ...     ...               ...
# 2016                            Yes  Yes  Yes     Yes               Yes
# 2017                            Yes  Yes  Yes     Yes               Yes
# 2018                            Yes  Yes  Yes     Yes               Yes
# 2019                            Yes  Yes  Yes     Yes         Sometimes
# 2020                            Yes  Yes  Yes     Yes               Yes
#
#      Raw vegetables Fruits Cereals (eg spelled, barley) Whole grains food  \
# 0               Yes    Yes                          NaN               Yes
# 1               Yes    Yes                          NaN               Yes
# 2               Yes     NO                          NaN               Yes
# 3               Yes    Yes                          NaN               Yes
# 4                NO    Yes                          NaN               Yes
# ...             ...    ...                          ...               ...
# 2016            Yes    Yes                          Yes               Yes
# 2017            Yes    Yes                           NO               Yes
# 2018            Yes    Yes                          Yes               Yes
# 2019            Yes    Yes                          Yes               Yes
# 2020            Yes    Yes                    Sometimes               Yes
#
#            Nuts       Tofu Dark chocolate  \
# 0           Yes        Yes            NaN
# 1           Yes        Yes            NaN
# 2           Yes        Yes            NaN
# 3           Yes        Yes            NaN
# 4            NO         NO            NaN
# ...         ...        ...            ...
# 2016  Sometimes  Sometimes            Yes
# 2017        Yes         NO            Yes
# 2018        Yes         NO            Yes
# 2019        Yes  Sometimes            Yes
# 2020        Yes         NO            Yes
#
#      Do you eat differently at the weekend?  \
# 0                   Yes, I eat more at home
# 1                 Yes, I eat at restaurants
# 2                 Yes, I eat at restaurants
# 3                 Yes, I eat at restaurants
# 4                                        No
# ...                                     ...
# 2016                  I cook more elaborate
# 2017              Yes, I eat at restaurants
# 2018              Yes, I eat at restaurants
# 2019                  I cook more elaborate
# 2020                                     No
#
#      Do you play a sport (at least 5 hours/week)?  \
# 0                                              No
# 1                                             Yes
# 2                                              No
# 3                                              No
# 4                                             Yes
# ...                                           ...
# 2016                                           No
# 2017                                          Yes
# 2018                                          Yes
# 2019                                           No
# 2020                                           No
#
#      When are you hungry during the day? Do you ever miss meals?  \
# 0                          Before Dinner                      No
# 1                         When I wake Up                      No
# 2                       In The Afternoon                     Yes
# 3                          Before Dinner                      No
# 4                       In The Afternoon                      No
# ...                                  ...                     ...
# 2016                  During the morning                      No
# 2017                    In The Afternoon          Yes, breakfast
# 2018                   I'm always hungry                      No
# 2019                    In The Afternoon                     Yes
# 2020                        After Dinner                      No
#
#      Do you ever eat distracted or not at the table? Do you eat fast?  \
# 0                                                 No               No
# 1                                                Yes              Yes
# 2                                                Yes              Yes
# 3                                                Yes              Yes
# 4                                                Yes              Yes
# ...                                              ...              ...
# 2016                                             Yes              Yes
# 2017                                             Yes              Yes
# 2018                                             Yes              Yes
# 2019                                             Yes              Yes
# 2020                                              No              Yes
#
#      Do you happen to eat uncontrollably even if you're not hungry?  \
# 0                                  Infrequent (1/month)
# 1                                                 Never
# 2                                             Every Day
# 3                                  Infrequent (1/month)
# 4                                       Often (>1/week)
# ...                                                 ...
# 2016                                    Often (>1/week)
# 2017                               Infrequent (1/month)
# 2018                                              Never
# 2019                               Infrequent (1/month)
# 2020                                    Often (>1/week)
#
#      Do you wake up to eat at night?  \
# 0                              Never
# 1                              Never
# 2                    Often (>1/week)
# 3                              Never
# 4               Infrequent (1/month)
# ...                              ...
# 2016                           Never
# 2017                           Never
# 2018                           Never
# 2019                           Never
# 2020            Infrequent (1/month)
#
#                     How do you sleep at night?  You like salty or sweet?  \
# 0                                         Good                        10
# 1                    I struggle to fall asleep                         9
# 2     I wake up several times during the night                         5
# 3     I wake up several times during the night                        10
# 4                                         Good                        10
# ...                                        ...                       ...
# 2016                 I struggle to fall asleep                         7
# 2017                                      Good                         8
# 2018                                      Good                         9
# 2019  I wake up several times during the night                         5
# 2020                                      Good                         8
#
#      Do you eat alone or together?  Do you eat out with meals?
# 0                    Often Togheter                        NaN
# 1                       Often Alone                        NaN
# 2                       Often Alone                        NaN
# 3                    Often Togheter                        NaN
# 4                    Often Togheter                        NaN
# ...                             ...                        ...
# 2016                            NaN           Together at work
# 2017                            NaN                         NO
# 2018                            NaN          Together at Lunch
# 2019                            NaN                         NO
# 2020                            NaN           Together at work
#
# [2021 rows x 34 columns]

# %%
data.columns
# Out:
# Index(['SEX', 'How many times do you eat a day?',
#        'How many liters of water do you drink per day?',
#        'How many times do you consume alcoholic beverages in a week?',
#        'How many sugary drinks do you consume per day?', 'Cow's milk',
#        'Vegetable drinks (eg soy milk)', 'Low-fat white yogurt',
#        'Fresh cheeses', 'Meat', 'Processed Meat (es prosciutto)', 'Fish',
#        'Eggs', 'Legumes', 'Cooked vegetables', 'Raw vegetables', 'Fruits',
#        'Cereals (eg spelled, barley)', 'Whole grains food', 'Nuts', 'Tofu',
#        'Dark chocolate', 'Do you eat differently at the weekend?',
#        'Do you play a sport (at least 5 hours/week)?',
#        'When are you hungry during the day?', 'Do you ever miss meals?',
#        'Do you ever eat distracted or not at the table?', 'Do you eat fast?',
#        'Do you happen to eat uncontrollably even if you're not hungry?',
#        'Do you wake up to eat at night?', 'How do you sleep at night?',
#        'You like salty or sweet?', 'Do you eat alone or together? ',
#        'Do you eat out with meals?'],
#       dtype='object')

# %%
data_1 = pd.read_csv('../data/Dataset.csv') #данные, которые мы собрали
data_1
# Out:
#      SEX  How many times do you eat a day? How many hours a day do you sleep?  \
# 0      M                                 1                                2-4
# 1      F                                 3                                5-6
# 2      F                                 3                                5-6
# 3      F                                 3                               9-10
# 4      F                                 4                                7-8
# ...   ..                               ...                                ...
# 1176   M                                 2                                2-4
# 1177   M                                 4                                2-4
# 1178   M                                 5                               9-10
# 1179   F                                 3                               More
# 1180   F                                 5                               More
#
#      How many times per week do you eat fastfood?  \
# 0                                               0
# 1                                               1
# 2                                               0
# 3                                               3
# 4                                               1
# ...                                           ...
# 1176                                            0
# 1177                                            1
# 1178                                            2
# 1179                                            2
# 1180                                            0
#
#      Average number of steps per day? Cow's milk  \
# 0                              0-4000        Yes
# 1                              0-4000        Yes
# 2                          7000-10000        Yes
# 3                           4000-7000         No
# 4                           4000-7000  Sometimes
# ...                               ...        ...
# 1176                           15000+  Sometimes
# 1177                        4000-7000         No
# 1178                       7000-10000  Sometimes
# 1179                           15000+  Sometimes
# 1180                      10000-15000         No
#
#      Vegetable drinks (eg soy milk) Low-fat white yogurt Fresh cheeses  \
# 0                               Yes                  Yes           Yes
# 1                                No                  Yes           Yes
# 2                               Yes                   No     Sometimes
# 3                               Yes                   No           Yes
# 4                               Yes            Sometimes           Yes
# ...                             ...                  ...           ...
# 1176                      Sometimes                  Yes            No
# 1177                             No            Sometimes     Sometimes
# 1178                             No            Sometimes     Sometimes
# 1179                      Sometimes            Sometimes           Yes
# 1180                             No                   No     Sometimes
#
#            Meat Processed Meat (es prosciutto)       Fish       Eggs  \
# 0           Yes                            Yes        Yes        Yes
# 1           Yes                             No        Yes        Yes
# 2           Yes                      Sometimes        Yes        Yes
# 3           Yes                             No        Yes        Yes
# 4            No                             No  Sometimes        Yes
# ...         ...                            ...        ...        ...
# 1176  Sometimes                            Yes         No        Yes
# 1177         No                      Sometimes        Yes  Sometimes
# 1178        Yes                            Yes        Yes         No
# 1179        Yes                            Yes  Sometimes  Sometimes
# 1180  Sometimes                             No         No         No
#
#         Legumes Cooked vegetables Raw vegetables     Fruits Whole grains food  \
# 0           Yes               Yes            Yes        Yes               Yes
# 1            No               Yes            Yes        Yes               Yes
# 2           Yes               Yes            Yes        Yes               Yes
# 3     Sometimes               Yes            Yes  Sometimes               Yes
# 4     Sometimes               Yes            Yes        Yes               Yes
# ...         ...               ...            ...        ...               ...
# 1176         No                No      Sometimes         No                No
# 1177         No                No             No        Yes               Yes
# 1178         No               Yes      Sometimes         No               Yes
# 1179         No                No             No         No         Sometimes
# 1180        Yes                No      Sometimes         No                No
#
#            Nuts       Tofu Do you eat differently at the weekend?  \
# 0           Yes        Yes                 Yes I eat more at home
# 1           Yes         No               Yes I eat at restaurants
# 2           Yes  Sometimes               Yes I eat at restaurants
# 3           Yes         No                  I cook more elaborate
# 4     Sometimes  Sometimes                                     No
# ...         ...        ...                                    ...
# 1176        Yes        Yes                                     No
# 1177         No         No                 Yes I eat more at home
# 1178  Sometimes  Sometimes                 Yes I eat more at home
# 1179         No         No               Yes I eat at restaurants
# 1180  Sometimes        Yes                  I cook more elaborate
#
#      Do you play a sport (at least 5 hours/week)?  \
# 0                                             Yes
# 1                                             Yes
# 2                                             Yes
# 3                                              No
# 4                                              No
# ...                                           ...
# 1176                                           No
# 1177                                           No
# 1178                                           No
# 1179                                          Yes
# 1180                                           No
#
#                 When are you hungry during the day?  \
# 0                                    When I wake Up
# 1                                    When I wake Up
# 2               During the morning,In the afternoon
# 3                                       After lunch
# 4     During the morning,Before lunch,Before Dinner
# ...                                             ...
# 1176                                 When I wake Up
# 1177                                  Before Dinner
# 1178                                   Before lunch
# 1179                                   After Dinner
# 1180                               In the afternoon
#
#                      What kind of snacks do you prefer?  \
# 0                                       Yes for craving
# 1                              Sweets,Fruits,vegetables
# 2              Fruits,vegetables,Sandwiches,Bars,breads
# 3                                     Fruits,vegetables
# 4     Sweets,Fruits,vegetables,Nuts,Sandwiches,Bars,...
# ...                                                 ...
# 1176                                    Yes for craving
# 1177                                         Sandwiches
# 1178                                         Sandwiches
# 1179                                         Sandwiches
# 1180                                             Sweets
#
#      Do you ever eat distracted or not at the table? Do you eat fast?  \
# 0                                                Yes              Yes
# 1                                                Yes              Yes
# 2                                                Yes              Yes
# 3                                                Yes               No
# 4                                                Yes              Yes
# ...                                              ...              ...
# 1176                                             Yes              Yes
# 1177                                             Yes              Yes
# 1178                                              No              Yes
# 1179                                             Yes               No
# 1180                                             Yes               No
#
#      Do you happen to eat uncontrollably even if you're not hungry?  \
# 0                                             Every day
# 1                                  Infrequent (1/month)
# 2                                  Infrequent (1/month)
# 3                                  Infrequent (1/month)
# 4                                       Often (>1/week)
# ...                                                 ...
# 1176                                    Often (>1/week)
# 1177                                    Often (>1/week)
# 1178                                    Often (>1/week)
# 1179                                              Never
# 1180                                              Never
#
#      Do you wake up to eat at night?  \
# 0                          Every day
# 1                              Never
# 2                              Never
# 3                              Never
# 4                              Never
# ...                              ...
# 1176                 Often (>1/week)
# 1177                           Never
# 1178            Infrequent (1/month)
# 1179            Infrequent (1/month)
# 1180                           Never
#
#                              How do you sleep at night?  \
# 0                                                  Good
# 1                                                  Good
# 2              I wake up several times during the night
# 3                             I struggle to fall asleep
# 4     I struggle to fall asleep,I wake up several ti...
# ...                                                 ...
# 1176           I wake up several times during the night
# 1177                          I struggle to fall asleep
# 1178                                               Good
# 1179           I wake up several times during the night
# 1180           I wake up a lot sooner than I would like
#
#       You like salty or sweet? (where 10 - "I love salt and hate sweet" and 1 - "I am the biggest fan of sweet")  \
# 0                                                     1
# 1                                                     4
# 2                                                     8
# 3                                                     5
# 4                                                     6
# ...                                                 ...
# 1176                                                  7
# 1177                                                  9
# 1178                                                 10
# 1179                                                  2
# 1180                                                  7
#
#      Do you eat alone or togheter?    Age  \
# 0                   Often Together   0-14
# 1                      Often Alone  15-20
# 2                   Often Together  15-20
# 3                   Often Together  15-20
# 4      Often Alone,Alone at dinner  15-20
# ...                            ...    ...
# 1176               Alone at dinner  15-20
# 1177            Alone at breakfast  31-50
# 1178               Alone at dinner  15-20
# 1179                Alone at lunch  15-20
# 1180                Alone at lunch  31-50
#
#       How many liters of water do you drink per day?  \
# 0                                                  0
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  3
# ...                                              ...
# 1176                                               4
# 1177                                               3
# 1178                                               1
# 1179                                               1
# 1180                                               4
#
#      How many times do you consume alcoholic beverages in a week?  \
# 0                                                     0
# 1                                                     1
# 2                                                     4
# 3                                                     0
# 4                                                     1
# ...                                                 ...
# 1176                                                  2
# 1177                                                  2
# 1178                                                  0
# 1179                                                  0
# 1180                                                  0
#
#      How stress affects on your eating habits?  \
# 0                     I'm starting to eat more
# 1                     I'm starting to eat less
# 2                     I'm starting to eat less
# 3                     I'm starting to eat less
# 4                     I'm starting to eat more
# ...                                        ...
# 1176                   Doesn't have any effect
# 1177                  I'm starting to eat less
# 1178                          I have no stress
# 1179                  I'm starting to eat more
# 1180                          I have no stress
#
#       How many sugary drinks do you consume per day?  \
# 0                                                  0
# 1                                                  2
# 2                                                  5
# 3                                                  1
# 4                                                  1
# ...                                              ...
# 1176                                               3
# 1177                                               0
# 1178                                               2
# 1179                                               3
# 1180                                               2
#
#                   Do you ever miss meals?
# 0                                      No
# 1                Yes lunch,I have no time
# 2     Yes lunch,Yes dinner,I have no time
# 3                          I have no time
# 4                          I have no time
# ...                                   ...
# 1176                            Yes lunch
# 1177                       I have no time
# 1178                            Yes lunch
# 1179                           Yes dinner
# 1180                                   No
#
# [1181 rows x 37 columns]

# %% [markdown]
# ## Данные
#
# Посмотрим
#
# - какие есть колонки в каждом наборе данных и сколько их
# - сколько строк
# - количество пропущенных ответов
#
# Удалим колонки, где много пропущенных ответов

# %%
data.shape #строк и колонок
# Out:
# (2021, 34)

# %%
data.describe() #описание только числовых признаков
# Out:
#        How many times do you eat a day?  \
# count                       2021.000000
# mean                           4.033647
# std                            1.043536
# min                            1.000000
# 25%                            3.000000
# 50%                            4.000000
# 75%                            5.000000
# max                            7.000000
#
#        How many liters of water do you drink per day?  \
# count                                     2021.000000
# mean                                         1.581890
# std                                          0.721555
# min                                          0.000000
# 25%                                          1.000000
# 50%                                          1.000000
# 75%                                          2.000000
# max                                          5.000000
#
#        How many times do you consume alcoholic beverages in a week?  \
# count                                        2021.000000
# mean                                            1.431470
# std                                             1.757834
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             7.000000
#
#        How many sugary drinks do you consume per day?  \
# count                                     2021.000000
# mean                                         1.719446
# std                                          1.732612
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          3.000000
# max                                          7.000000
#
#        You like salty or sweet?
# count               2021.000000
# mean                   6.337457
# std                    2.629785
# min                    1.000000
# 25%                    5.000000
# 50%                    6.000000
# 75%                    8.000000
# max                   10.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2021 entries, 0 to 2020
# Data columns (total 34 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   SEX                                                             2021 non-null   object
#  1   How many times do you eat a day?                                2021 non-null   int64
#  2   How many liters of water do you drink per day?                  2021 non-null   int64
#  3   How many times do you consume alcoholic beverages in a week?    2021 non-null   int64
#  4   How many sugary drinks do you consume per day?                  2021 non-null   int64
#  5   Cow's milk                                                      2021 non-null   object
#  6   Vegetable drinks (eg soy milk)                                  2021 non-null   object
#  7   Low-fat white yogurt                                            2021 non-null   object
#  8   Fresh cheeses                                                   2021 non-null   object
#  9   Meat                                                            2021 non-null   object
#  10  Processed Meat (es prosciutto)                                  2021 non-null   object
#  11  Fish                                                            2021 non-null   object
#  12  Eggs                                                            2021 non-null   object
#  13  Legumes                                                         2021 non-null   object
#  14  Cooked vegetables                                               2021 non-null   object
#  15  Raw vegetables                                                  2021 non-null   object
#  16  Fruits                                                          2021 non-null   object
#  17  Cereals (eg spelled, barley)                                    978 non-null    object
#  18  Whole grains food                                               2021 non-null   object
#  19  Nuts                                                            2021 non-null   object
#  20  Tofu                                                            2021 non-null   object
#  21  Dark chocolate                                                  420 non-null    object
#  22  Do you eat differently at the weekend?                          2021 non-null   object
#  23  Do you play a sport (at least 5 hours/week)?                    2021 non-null   object
#  24  When are you hungry during the day?                             2021 non-null   object
#  25  Do you ever miss meals?                                         2021 non-null   object
#  26  Do you ever eat distracted or not at the table?                 2021 non-null   object
#  27  Do you eat fast?                                                2021 non-null   object
#  28  Do you happen to eat uncontrollably even if you're not hungry?  2021 non-null   object
#  29  Do you wake up to eat at night?                                 2021 non-null   object
#  30  How do you sleep at night?                                      2021 non-null   object
#  31  You like salty or sweet?                                        2021 non-null   int64
#  32  Do you eat alone or together?                                   1045 non-null   object
#  33  Do you eat out with meals?                                      976 non-null    object
# dtypes: int64(5), object(29)
# memory usage: 537.0+ KB

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1181 entries, 0 to 1180
# Data columns (total 37 columns):
#  #   Column                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                      --------------  -----
#  0   SEX                                                                                                         1181 non-null   object
#  1   How many times do you eat a day?                                                                            1181 non-null   int64
#  2   How many hours a day do you sleep?                                                                          1181 non-null   object
#  3   How many times per week do you eat fastfood?                                                                1181 non-null   object
#  4   Average number of steps per day?                                                                            1181 non-null   object
#  5   Cow's milk                                                                                                  1181 non-null   object
#  6   Vegetable drinks (eg soy milk)                                                                              1181 non-null   object
#  7   Low-fat white yogurt                                                                                        1181 non-null   object
#  8   Fresh cheeses                                                                                               1181 non-null   object
#  9   Meat                                                                                                        1181 non-null   object
#  10  Processed Meat (es prosciutto)                                                                              1181 non-null   object
#  11  Fish                                                                                                        1181 non-null   object
#  12  Eggs                                                                                                        1181 non-null   object
#  13  Legumes                                                                                                     1181 non-null   object
#  14  Cooked vegetables                                                                                           1181 non-null   object
#  15  Raw vegetables                                                                                              1181 non-null   object
#  16  Fruits                                                                                                      1181 non-null   object
#  17  Whole grains food                                                                                           1181 non-null   object
#  18  Nuts                                                                                                        1181 non-null   object
#  19  Tofu                                                                                                        1181 non-null   object
#  20  Do you eat differently at the weekend?                                                                      1181 non-null   object
#  21  Do you play a sport (at least 5 hours/week)?                                                                1181 non-null   object
#  22  When are you hungry during the day?                                                                         1181 non-null   object
#  23  What kind of snacks do you prefer?                                                                          1181 non-null   object
#  24  Do you ever eat distracted or not at the table?                                                             1181 non-null   object
#  25  Do you eat fast?                                                                                            1181 non-null   object
#  26  Do you happen to eat uncontrollably even if you're not hungry?                                              1181 non-null   object
#  27  Do you wake up to eat at night?                                                                             1181 non-null   object
#  28  How do you sleep at night?                                                                                  1181 non-null   object
#  29  You like salty or sweet? (where 10 - "I love salt and hate sweet" and 1 - "I am the biggest fan of sweet")  1181 non-null   int64
#  30  Do you eat alone or togheter?                                                                               1181 non-null   object
#  31  Age                                                                                                         1181 non-null   object
#  32  How many liters of water do you drink per day?                                                              1181 non-null   int64
#  33  How many times do you consume alcoholic beverages in a week?                                                1181 non-null   object
#  34  How stress affects on your eating habits?                                                                   1181 non-null   object
#  35  How many sugary drinks do you consume per day?                                                              1181 non-null   int64
#  36  Do you ever miss meals?                                                                                     1181 non-null   object
# dtypes: int64(4), object(33)
# memory usage: 341.5+ KB

# %% [markdown]
# ### Таблица с вопросами, типами ответов и кол-во не пустых строк в каждом вопросе
#
# Посмотрим только на первый набор данных, так как в нашем нет пропусков

# %%
from tabulate import tabulate

# %%
headers = ["Column Name", "Data Type", "Non-Null Count"]
datatable = [[col, data[col].dtype, data[col].count()] for col in data.columns]
table = tabulate(datatable, headers=headers, tablefmt="pretty")
print(table)
# Out:
# +----------------------------------------------------------------+-----------+----------------+
# |                          Column Name                           | Data Type | Non-Null Count |
# +----------------------------------------------------------------+-----------+----------------+
# |                              SEX                               |  object   |      2021      |
# |                How many times do you eat a day?                |   int64   |      2021      |
# |         How many liters of water do you drink per day?         |   int64   |      2021      |
# |  How many times do you consume alcoholic beverages in a week?  |   int64   |      2021      |
# |         How many sugary drinks do you consume per day?         |   int64   |      2021      |
# |                           Cow's milk                           |  object   |      2021      |
# |                 Vegetable drinks (eg soy milk)                 |  object   |      2021      |
# |                      Low-fat white yogurt                      |  object   |      2021      |
# |                         Fresh cheeses                          |  object   |      2021      |
# |                              Meat                              |  object   |      2021      |
# |                 Processed Meat (es prosciutto)                 |  object   |      2021      |
# |                              Fish                              |  object   |      2021      |
# |                              Eggs                              |  object   |      2021      |
# |                            Legumes                             |  object   |      2021      |
# |                       Cooked vegetables                        |  object   |      2021      |
# |                         Raw vegetables                         |  object   |      2021      |
# |                             Fruits                             |  object   |      2021      |
# |                  Cereals (eg spelled, barley)                  |  object   |      978       |
# |                       Whole grains food                        |  object   |      2021      |
# |                              Nuts                              |  object   |      2021      |
# |                              Tofu                              |  object   |      2021      |
# |                         Dark chocolate                         |  object   |      420       |
# |             Do you eat differently at the weekend?             |  object   |      2021      |
# |          Do you play a sport (at least 5 hours/week)?          |  object   |      2021      |
# |              When are you hungry during the day?               |  object   |      2021      |
# |                    Do you ever miss meals?                     |  object   |      2021      |
# |        Do you ever eat distracted or not at the table?         |  object   |      2021      |
# |                        Do you eat fast?                        |  object   |      2021      |
# | Do you happen to eat uncontrollably even if you're not hungry? |  object   |      2021      |
# |                Do you wake up to eat at night?                 |  object   |      2021      |
# |                   How do you sleep at night?                   |  object   |      2021      |
# |                    You like salty or sweet?                    |   int64   |      2021      |
# |                 Do you eat alone or together?                  |  object   |      1045      |
# |                   Do you eat out with meals?                   |  object   |      976       |
# +----------------------------------------------------------------+-----------+----------------+

# %% [markdown]
# # Подготовка данных
#
# - **Удаление ненужных столбцов** (содержат слишком много недостающих данных)
#
# - **Объединение двух наборов данных**
#
# - **Идентификация повторяющихся столбцов**
#
# - **Переименование столбцов и строк** (чтобы сделать их более информативными и/или более понятными)

# %%
data.isna().sum()
# Out:
# SEX                                                                  0
# How many times do you eat a day?                                     0
# How many liters of water do you drink per day?                       0
# How many times do you consume alcoholic beverages in a week?         0
# How many sugary drinks do you consume per day?                       0
# Cow's milk                                                           0
# Vegetable drinks (eg soy milk)                                       0
# Low-fat white yogurt                                                 0
# Fresh cheeses                                                        0
# Meat                                                                 0
# Processed Meat (es prosciutto)                                       0
# Fish                                                                 0
# Eggs                                                                 0
# Legumes                                                              0
# Cooked vegetables                                                    0
# Raw vegetables                                                       0
# Fruits                                                               0
# Cereals (eg spelled, barley)                                      1043
# Whole grains food                                                    0
# Nuts                                                                 0
# Tofu                                                                 0
# Dark chocolate                                                    1601
# Do you eat differently at the weekend?                               0
# Do you play a sport (at least 5 hours/week)?                         0
# When are you hungry during the day?                                  0
# Do you ever miss meals?                                              0
# Do you ever eat distracted or not at the table?                      0
# Do you eat fast?                                                     0
# Do you happen to eat uncontrollably even if you're not hungry?       0
# Do you wake up to eat at night?                                      0
# How do you sleep at night?                                           0
# You like salty or sweet?                                             0
# Do you eat alone or together?                                      976
# Do you eat out with meals?                                        1045
# dtype: int64

# %% [markdown]
# ### Удаление колонок с NAN

# %%
columns_to_drop = ['Cereals (eg spelled, barley)',
                   'Dark chocolate',
                   'Do you eat out with meals?',
                  'Do you eat alone or together? ']

data = data.drop(columns=columns_to_drop, axis=1)

# %%
data.shape
# Out:
# (2021, 30)

# %% [markdown]
# ### Найдем общие колонки у двух наборов данных

# %%
data_columns = data.columns.tolist()
data_1_columns = data_1.columns.tolist()

# %%
common_columns = list(set(data_columns) & set(data_1_columns))
len(common_columns)
# Out:
# 29

# %%
data_columns
# Out:
# ['SEX',
#  'How many times do you eat a day?',
#  'How many liters of water do you drink per day?',
#  'How many times do you consume alcoholic beverages in a week?',
#  'How many sugary drinks do you consume per day?',
#  "Cow's milk",
#  'Vegetable drinks (eg soy milk)',
#  'Low-fat white yogurt',
#  'Fresh cheeses',
#  'Meat',
#  'Processed Meat (es prosciutto)',
#  'Fish',
#  'Eggs',
#  'Legumes',
#  'Cooked vegetables',
#  'Raw vegetables',
#  'Fruits',
#  'Whole grains food',
#  'Nuts',
#  'Tofu',
#  'Do you eat differently at the weekend?',
#  'Do you play a sport (at least 5 hours/week)?',
#  'When are you hungry during the day?',
#  'Do you ever miss meals?',
#  'Do you ever eat distracted or not at the table?',
#  'Do you eat fast?',
#  "Do you happen to eat uncontrollably even if you're not hungry?",
#  'Do you wake up to eat at night?',
#  'How do you sleep at night?',
#  'You like salty or sweet?']

# %%
unique_columns_dataset_renamed = set(data_columns) - set(data_1_columns) # вопросы, которые есть в найденных данных, нет у нас
unique_columns_dataset_renamed
# Out:
# {'You like salty or sweet?'}

# %%
unique_columns_data_1 = set(data_1_columns) - set(data_columns) # вопросы, которых нет в найденных данных
unique_columns_data_1
# Out:
# {'Age',
#  'Average number of steps per day?',
#  'Do you eat alone or togheter?',
#  'How many hours a day do you sleep?',
#  'How many times per week do you eat fastfood?',
#  'How stress affects on your eating habits?',
#  'What kind of snacks do you prefer?',
#  'You like salty or sweet? (where 10 - "I love salt and hate sweet" and 1 - "I am the biggest fan of sweet")'}

# %%
# определение общих колонок 
common_columns = [
    'Tofu',
    'How many liters of water do you drink per day?',
    'Processed Meat (es prosciutto)',
    'SEX',
    'Do you play a sport (at least 5 hours/week)?',
    'Do you eat differently at the weekend?',
    'How do you sleep at night?',
    'How many sugary drinks do you consume per day?',
    'Raw vegetables',
    "Cow's milk",
    'Fresh cheeses',
    'Do you ever miss meals?',
    'Vegetable drinks (eg soy milk)',
    'Do you eat fast?',
    'Cooked vegetables',
    'Low-fat white yogurt',
    'Do you ever eat distracted or not at the table?',
    'Do you wake up to eat at night?',
    'When are you hungry during the day?',
    'How many times do you eat a day?',
    'Nuts',
    'Legumes',
    'Fish',
    'Fruits',
    'Eggs',
    'Whole grains food',
    "Do you happen to eat uncontrollably even if you're not hungry?",
    'How many times do you consume alcoholic beverages in a week?',
    'Meat'
]

filtered_dataset_renamed = data[common_columns]
filtered_modified_per_statistica = data_1[common_columns]

con_df = pd.concat([filtered_dataset_renamed, filtered_modified_per_statistica], ignore_index=True)

con_df.shape
# Out:
# (3202, 29)

# %% [markdown]
# ### Нахождение и удаление строк-дубликатов

# %%
con_df.loc[con_df.duplicated()]
# Out:
#            Tofu  How many liters of water do you drink per day?  \
# 13    Sometimes                                               2
# 21    Sometimes                                               1
# 28           NO                                               1
# 29           NO                                               1
# 91          Yes                                               2
# ...         ...                                             ...
# 2637         No                                               3
# 2639         No                                               3
# 2644         No                                               3
# 2829        Yes                                               1
# 2830        Yes                                               1
#
#      Processed Meat (es prosciutto) SEX  \
# 13                              Yes   M
# 21                              Yes   F
# 28                              Yes   F
# 29                              Yes   F
# 91                              Yes   F
# ...                             ...  ..
# 2637                            Yes   F
# 2639                            Yes   F
# 2644                            Yes   F
# 2829                            Yes   M
# 2830                            Yes   M
#
#      Do you play a sport (at least 5 hours/week)?  \
# 13                                            Yes
# 21                                             No
# 28                                            Yes
# 29                                            Yes
# 91                                             No
# ...                                           ...
# 2637                                          Yes
# 2639                                          Yes
# 2644                                          Yes
# 2829                                           No
# 2830                                           No
#
#      Do you eat differently at the weekend?  \
# 13                  Yes, I eat more at home
# 21                  Yes, I eat more at home
# 28                    I cook more elaborate
# 29                    I cook more elaborate
# 91                Yes, I eat at restaurants
# ...                                     ...
# 2637                 Yes I eat more at home
# 2639                 Yes I eat more at home
# 2644                 Yes I eat more at home
# 2829                 Yes I eat more at home
# 2830                 Yes I eat more at home
#
#                     How do you sleep at night?  \
# 13                                        Good
# 21    I wake up a lot sooner than I would like
# 28    I wake up a lot sooner than I would like
# 29    I wake up a lot sooner than I would like
# 91                                        Good
# ...                                        ...
# 2637                                      Good
# 2639                                      Good
# 2644                                      Good
# 2829  I wake up a lot sooner than I would like
# 2830  I wake up a lot sooner than I would like
#
#       How many sugary drinks do you consume per day? Raw vegetables  \
# 13                                                 1             NO
# 21                                                 3     Don't know
# 28                                                 1     Don't know
# 29                                                 1     Don't know
# 91                                                 3            Yes
# ...                                              ...            ...
# 2637                                               0            Yes
# 2639                                               0            Yes
# 2644                                               0            Yes
# 2829                                               1            Yes
# 2830                                               1            Yes
#
#      Cow's milk Fresh cheeses Do you ever miss meals?  \
# 13          Yes     Sometimes          Yes, breakfast
# 21          Yes           Yes                     Yes
# 28           NO           Yes                      No
# 29           NO           Yes                      No
# 91           NO           Yes                      No
# ...         ...           ...                     ...
# 2637        Yes           Yes                      No
# 2639        Yes           Yes                      No
# 2644         No           Yes                      No
# 2829        Yes           Yes           Yes breakfast
# 2830        Yes           Yes           Yes breakfast
#
#      Vegetable drinks (eg soy milk) Do you eat fast? Cooked vegetables  \
# 13                               NO               No               Yes
# 21                        Sometimes              Yes               Yes
# 28                               NO               No               Yes
# 29                               NO               No               Yes
# 91                              Yes              Yes               Yes
# ...                             ...              ...               ...
# 2637                      Sometimes              Yes               Yes
# 2639                      Sometimes              Yes               Yes
# 2644                      Sometimes              Yes               Yes
# 2829                            Yes               No               Yes
# 2830                            Yes               No               Yes
#
#      Low-fat white yogurt Do you ever eat distracted or not at the table?  \
# 13              Sometimes                                              No
# 21                    Yes                                             Yes
# 28                     NO                                             Yes
# 29                     NO                                             Yes
# 91              Sometimes                                             Yes
# ...                   ...                                             ...
# 2637                   No                                              No
# 2639                   No                                              No
# 2644            Sometimes                                              No
# 2829                  Yes                                              No
# 2830                  Yes                                              No
#
#      Do you wake up to eat at night? When are you hungry during the day?  \
# 13                             Never                    In The Afternoon
# 21                             Never                       Before Dinner
# 28                             Never                    In The Afternoon
# 29                             Never                    In The Afternoon
# 91                             Never                  During the morning
# ...                              ...                                 ...
# 2637                           Never                      When I wake Up
# 2639                           Never                      When I wake Up
# 2644                           Never                      When I wake Up
# 2829                           Never                  During the morning
# 2830                           Never                  During the morning
#
#       How many times do you eat a day? Nuts    Legumes       Fish     Fruits  \
# 13                                   4   NO        Yes        Yes  Sometimes
# 21                                   4  Yes  Sometimes        Yes        Yes
# 28                                   4   NO        Yes        Yes        Yes
# 29                                   4   NO        Yes        Yes        Yes
# 91                                   3  Yes        Yes        Yes        Yes
# ...                                ...  ...        ...        ...        ...
# 2637                                 6  Yes         No  Sometimes        Yes
# 2639                                 6  Yes         No  Sometimes        Yes
# 2644                                 6  Yes         No  Sometimes        Yes
# 2829                                 1  Yes        Yes        Yes        Yes
# 2830                                 1  Yes        Yes        Yes        Yes
#
#            Eggs Whole grains food  \
# 13          Yes         Sometimes
# 21          Yes               Yes
# 28          Yes               Yes
# 29          Yes               Yes
# 91    Sometimes               Yes
# ...         ...               ...
# 2637        Yes               Yes
# 2639        Yes               Yes
# 2644        Yes               Yes
# 2829        Yes               Yes
# 2830        Yes               Yes
#
#      Do you happen to eat uncontrollably even if you're not hungry?  \
# 13                                                Never
# 21                                      Often (>1/week)
# 28                                 Infrequent (1/month)
# 29                                 Infrequent (1/month)
# 91                                                Never
# ...                                                 ...
# 2637                                              Never
# 2639                                              Never
# 2644                                              Never
# 2829                               Infrequent (1/month)
# 2830                               Infrequent (1/month)
#
#      How many times do you consume alcoholic beverages in a week? Meat
# 13                                                    1            Yes
# 21                                                    1            Yes
# 28                                                    1            Yes
# 29                                                    1            Yes
# 91                                                    1            Yes
# ...                                                 ...            ...
# 2637                                                  0            Yes
# 2639                                                  0            Yes
# 2644                                                  0            Yes
# 2829                                                  1            Yes
# 2830                                                  1            Yes
#
# [85 rows x 29 columns]

# %%
con_df[con_df.duplicated(keep=False)]
# Out:
#            Tofu  How many liters of water do you drink per day?  \
# 11    Sometimes                                               2
# 13    Sometimes                                               2
# 20    Sometimes                                               1
# 21    Sometimes                                               1
# 27           NO                                               1
# ...         ...                                             ...
# 2639         No                                               3
# 2644         No                                               3
# 2828        Yes                                               1
# 2829        Yes                                               1
# 2830        Yes                                               1
#
#      Processed Meat (es prosciutto) SEX  \
# 11                              Yes   M
# 13                              Yes   M
# 20                              Yes   F
# 21                              Yes   F
# 27                              Yes   F
# ...                             ...  ..
# 2639                            Yes   F
# 2644                            Yes   F
# 2828                            Yes   M
# 2829                            Yes   M
# 2830                            Yes   M
#
#      Do you play a sport (at least 5 hours/week)?  \
# 11                                            Yes
# 13                                            Yes
# 20                                             No
# 21                                             No
# 27                                            Yes
# ...                                           ...
# 2639                                          Yes
# 2644                                          Yes
# 2828                                           No
# 2829                                           No
# 2830                                           No
#
#      Do you eat differently at the weekend?  \
# 11                  Yes, I eat more at home
# 13                  Yes, I eat more at home
# 20                  Yes, I eat more at home
# 21                  Yes, I eat more at home
# 27                    I cook more elaborate
# ...                                     ...
# 2639                 Yes I eat more at home
# 2644                 Yes I eat more at home
# 2828                 Yes I eat more at home
# 2829                 Yes I eat more at home
# 2830                 Yes I eat more at home
#
#                     How do you sleep at night?  \
# 11                                        Good
# 13                                        Good
# 20    I wake up a lot sooner than I would like
# 21    I wake up a lot sooner than I would like
# 27    I wake up a lot sooner than I would like
# ...                                        ...
# 2639                                      Good
# 2644                                      Good
# 2828  I wake up a lot sooner than I would like
# 2829  I wake up a lot sooner than I would like
# 2830  I wake up a lot sooner than I would like
#
#       How many sugary drinks do you consume per day? Raw vegetables  \
# 11                                                 1             NO
# 13                                                 1             NO
# 20                                                 3     Don't know
# 21                                                 3     Don't know
# 27                                                 1     Don't know
# ...                                              ...            ...
# 2639                                               0            Yes
# 2644                                               0            Yes
# 2828                                               1            Yes
# 2829                                               1            Yes
# 2830                                               1            Yes
#
#      Cow's milk Fresh cheeses Do you ever miss meals?  \
# 11          Yes     Sometimes          Yes, breakfast
# 13          Yes     Sometimes          Yes, breakfast
# 20          Yes           Yes                     Yes
# 21          Yes           Yes                     Yes
# 27           NO           Yes                      No
# ...         ...           ...                     ...
# 2639        Yes           Yes                      No
# 2644         No           Yes                      No
# 2828        Yes           Yes           Yes breakfast
# 2829        Yes           Yes           Yes breakfast
# 2830        Yes           Yes           Yes breakfast
#
#      Vegetable drinks (eg soy milk) Do you eat fast? Cooked vegetables  \
# 11                               NO               No               Yes
# 13                               NO               No               Yes
# 20                        Sometimes              Yes               Yes
# 21                        Sometimes              Yes               Yes
# 27                               NO               No               Yes
# ...                             ...              ...               ...
# 2639                      Sometimes              Yes               Yes
# 2644                      Sometimes              Yes               Yes
# 2828                            Yes               No               Yes
# 2829                            Yes               No               Yes
# 2830                            Yes               No               Yes
#
#      Low-fat white yogurt Do you ever eat distracted or not at the table?  \
# 11              Sometimes                                              No
# 13              Sometimes                                              No
# 20                    Yes                                             Yes
# 21                    Yes                                             Yes
# 27                     NO                                             Yes
# ...                   ...                                             ...
# 2639                   No                                              No
# 2644            Sometimes                                              No
# 2828                  Yes                                              No
# 2829                  Yes                                              No
# 2830                  Yes                                              No
#
#      Do you wake up to eat at night? When are you hungry during the day?  \
# 11                             Never                    In The Afternoon
# 13                             Never                    In The Afternoon
# 20                             Never                       Before Dinner
# 21                             Never                       Before Dinner
# 27                             Never                    In The Afternoon
# ...                              ...                                 ...
# 2639                           Never                      When I wake Up
# 2644                           Never                      When I wake Up
# 2828                           Never                  During the morning
# 2829                           Never                  During the morning
# 2830                           Never                  During the morning
#
#       How many times do you eat a day? Nuts    Legumes       Fish     Fruits  \
# 11                                   4   NO        Yes        Yes  Sometimes
# 13                                   4   NO        Yes        Yes  Sometimes
# 20                                   4  Yes  Sometimes        Yes        Yes
# 21                                   4  Yes  Sometimes        Yes        Yes
# 27                                   4   NO        Yes        Yes        Yes
# ...                                ...  ...        ...        ...        ...
# 2639                                 6  Yes         No  Sometimes        Yes
# 2644                                 6  Yes         No  Sometimes        Yes
# 2828                                 1  Yes        Yes        Yes        Yes
# 2829                                 1  Yes        Yes        Yes        Yes
# 2830                                 1  Yes        Yes        Yes        Yes
#
#      Eggs Whole grains food  \
# 11    Yes         Sometimes
# 13    Yes         Sometimes
# 20    Yes               Yes
# 21    Yes               Yes
# 27    Yes               Yes
# ...   ...               ...
# 2639  Yes               Yes
# 2644  Yes               Yes
# 2828  Yes               Yes
# 2829  Yes               Yes
# 2830  Yes               Yes
#
#      Do you happen to eat uncontrollably even if you're not hungry?  \
# 11                                                Never
# 13                                                Never
# 20                                      Often (>1/week)
# 21                                      Often (>1/week)
# 27                                 Infrequent (1/month)
# ...                                                 ...
# 2639                                              Never
# 2644                                              Never
# 2828                               Infrequent (1/month)
# 2829                               Infrequent (1/month)
# 2830                               Infrequent (1/month)
#
#      How many times do you consume alcoholic beverages in a week? Meat
# 11                                                    1            Yes
# 13                                                    1            Yes
# 20                                                    1            Yes
# 21                                                    1            Yes
# 27                                                    1            Yes
# ...                                                 ...            ...
# 2639                                                  0            Yes
# 2644                                                  0            Yes
# 2828                                                  1            Yes
# 2829                                                  1            Yes
# 2830                                                  1            Yes
#
# [143 rows x 29 columns]

# %%
df = con_df.drop_duplicates() #новый df, который будет содержать только уникальные строки из исходного DataFrame 
df
# Out:
#            Tofu  How many liters of water do you drink per day?  \
# 0           Yes                                               2
# 1           Yes                                               3
# 2           Yes                                               1
# 3           Yes                                               2
# 4            NO                                               1
# ...         ...                                             ...
# 3197        Yes                                               4
# 3198         No                                               3
# 3199  Sometimes                                               1
# 3200         No                                               1
# 3201        Yes                                               4
#
#      Processed Meat (es prosciutto) SEX  \
# 0                               Yes   M
# 1                               Yes   M
# 2                               Yes   F
# 3                               Yes   F
# 4                               Yes   M
# ...                             ...  ..
# 3197                            Yes   M
# 3198                      Sometimes   M
# 3199                            Yes   M
# 3200                            Yes   F
# 3201                             No   F
#
#      Do you play a sport (at least 5 hours/week)?  \
# 0                                              No
# 1                                             Yes
# 2                                              No
# 3                                              No
# 4                                             Yes
# ...                                           ...
# 3197                                           No
# 3198                                           No
# 3199                                           No
# 3200                                          Yes
# 3201                                           No
#
#      Do you eat differently at the weekend?  \
# 0                   Yes, I eat more at home
# 1                 Yes, I eat at restaurants
# 2                 Yes, I eat at restaurants
# 3                 Yes, I eat at restaurants
# 4                                        No
# ...                                     ...
# 3197                                     No
# 3198                 Yes I eat more at home
# 3199                 Yes I eat more at home
# 3200               Yes I eat at restaurants
# 3201                  I cook more elaborate
#
#                     How do you sleep at night?  \
# 0                                         Good
# 1                    I struggle to fall asleep
# 2     I wake up several times during the night
# 3     I wake up several times during the night
# 4                                         Good
# ...                                        ...
# 3197  I wake up several times during the night
# 3198                 I struggle to fall asleep
# 3199                                      Good
# 3200  I wake up several times during the night
# 3201  I wake up a lot sooner than I would like
#
#       How many sugary drinks do you consume per day? Raw vegetables  \
# 0                                                  1            Yes
# 1                                                  1            Yes
# 2                                                  3            Yes
# 3                                                  1            Yes
# 4                                                  3             NO
# ...                                              ...            ...
# 3197                                               3      Sometimes
# 3198                                               0             No
# 3199                                               2      Sometimes
# 3200                                               3             No
# 3201                                               2      Sometimes
#
#      Cow's milk Fresh cheeses Do you ever miss meals?  \
# 0           Yes           Yes                      No
# 1           Yes           Yes                      No
# 2            NO     Sometimes                     Yes
# 3           Yes            NO                      No
# 4            NO            NO                      No
# ...         ...           ...                     ...
# 3197  Sometimes            No               Yes lunch
# 3198         No     Sometimes          I have no time
# 3199  Sometimes     Sometimes               Yes lunch
# 3200  Sometimes           Yes              Yes dinner
# 3201         No     Sometimes                      No
#
#      Vegetable drinks (eg soy milk) Do you eat fast? Cooked vegetables  \
# 0                               Yes               No               Yes
# 1                               Yes              Yes               Yes
# 2                               Yes              Yes                NO
# 3                               Yes              Yes               Yes
# 4                                NO              Yes                NO
# ...                             ...              ...               ...
# 3197                      Sometimes              Yes                No
# 3198                             No              Yes                No
# 3199                             No              Yes               Yes
# 3200                      Sometimes               No                No
# 3201                             No               No                No
#
#      Low-fat white yogurt Do you ever eat distracted or not at the table?  \
# 0                      NO                                              No
# 1                     Yes                                             Yes
# 2                      NO                                             Yes
# 3                      NO                                             Yes
# 4                      NO                                             Yes
# ...                   ...                                             ...
# 3197                  Yes                                             Yes
# 3198            Sometimes                                             Yes
# 3199            Sometimes                                              No
# 3200            Sometimes                                             Yes
# 3201                   No                                             Yes
#
#      Do you wake up to eat at night? When are you hungry during the day?  \
# 0                              Never                       Before Dinner
# 1                              Never                      When I wake Up
# 2                    Often (>1/week)                    In The Afternoon
# 3                              Never                       Before Dinner
# 4               Infrequent (1/month)                    In The Afternoon
# ...                              ...                                 ...
# 3197                 Often (>1/week)                      When I wake Up
# 3198                           Never                       Before Dinner
# 3199            Infrequent (1/month)                        Before lunch
# 3200            Infrequent (1/month)                        After Dinner
# 3201                           Never                    In the afternoon
#
#       How many times do you eat a day?       Nuts Legumes       Fish Fruits  \
# 0                                    5        Yes     Yes        Yes    Yes
# 1                                    6        Yes     Yes        Yes    Yes
# 2                                    3        Yes     Yes         NO     NO
# 3                                    4        Yes     Yes        Yes    Yes
# 4                                    5         NO     Yes        Yes    Yes
# ...                                ...        ...     ...        ...    ...
# 3197                                 2        Yes      No         No     No
# 3198                                 4         No      No        Yes    Yes
# 3199                                 5  Sometimes      No        Yes     No
# 3200                                 3         No      No  Sometimes     No
# 3201                                 5  Sometimes     Yes         No     No
#
#            Eggs Whole grains food  \
# 0           Yes               Yes
# 1           Yes               Yes
# 2            NO               Yes
# 3           Yes               Yes
# 4            NO               Yes
# ...         ...               ...
# 3197        Yes                No
# 3198  Sometimes               Yes
# 3199         No               Yes
# 3200  Sometimes         Sometimes
# 3201         No                No
#
#      Do you happen to eat uncontrollably even if you're not hungry?  \
# 0                                  Infrequent (1/month)
# 1                                                 Never
# 2                                             Every Day
# 3                                  Infrequent (1/month)
# 4                                       Often (>1/week)
# ...                                                 ...
# 3197                                    Often (>1/week)
# 3198                                    Often (>1/week)
# 3199                                    Often (>1/week)
# 3200                                              Never
# 3201                                              Never
#
#      How many times do you consume alcoholic beverages in a week?       Meat
# 0                                                     1                  Yes
# 1                                                     1                  Yes
# 2                                                     3                  Yes
# 3                                                     1                  Yes
# 4                                                     1                  Yes
# ...                                                 ...                  ...
# 3197                                                  2            Sometimes
# 3198                                                  2                   No
# 3199                                                  0                  Yes
# 3200                                                  0                  Yes
# 3201                                                  0            Sometimes
#
# [3117 rows x 29 columns]

# %%
df.isna().sum()
# Out:
# Tofu                                                              0
# How many liters of water do you drink per day?                    0
# Processed Meat (es prosciutto)                                    0
# SEX                                                               0
# Do you play a sport (at least 5 hours/week)?                      0
# Do you eat differently at the weekend?                            0
# How do you sleep at night?                                        0
# How many sugary drinks do you consume per day?                    0
# Raw vegetables                                                    0
# Cow's milk                                                        0
# Fresh cheeses                                                     0
# Do you ever miss meals?                                           0
# Vegetable drinks (eg soy milk)                                    0
# Do you eat fast?                                                  0
# Cooked vegetables                                                 0
# Low-fat white yogurt                                              0
# Do you ever eat distracted or not at the table?                   0
# Do you wake up to eat at night?                                   0
# When are you hungry during the day?                               0
# How many times do you eat a day?                                  0
# Nuts                                                              0
# Legumes                                                           0
# Fish                                                              0
# Fruits                                                            0
# Eggs                                                              0
# Whole grains food                                                 0
# Do you happen to eat uncontrollably even if you're not hungry?    0
# How many times do you consume alcoholic beverages in a week?      0
# Meat                                                              0
# dtype: int64

# %% [markdown]
# ### Посмотрим, какие уникальные ответы есть в каждой колонке, и преобразуем их

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(len(unique_values))
    print(f"Unique values in '{column}': {unique_values}")
# Out:
# 5
# Unique values in 'Tofu': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 6
# Unique values in 'How many liters of water do you drink per day?': [2 3 1 4 5 0]
# 5
# Unique values in 'Processed Meat (es prosciutto)': ['Yes' 'Sometimes' 'NO' "Don't know" 'No']
# 2
# Unique values in 'SEX': ['M' 'F']
# 2
# Unique values in 'Do you play a sport (at least 5 hours/week)?': ['No' 'Yes']
# 6
# Unique values in 'Do you eat differently at the weekend?': ['Yes, I eat more at home' 'Yes, I eat at restaurants' 'No'
#  'I cook more elaborate' 'Yes I eat more at home'
#  'Yes I eat at restaurants']
# 12
# Unique values in 'How do you sleep at night?': ['Good' 'I struggle to fall asleep'
#  'I wake up several times during the night'
#  'I wake up a lot sooner than I would like'
#  'I struggle to fall asleep,I wake up several times during the night'
#  'Good,I struggle to fall asleep'
#  'I struggle to fall asleep,I wake up several times during the night,I wake up a lot sooner than I would like'
#  'I wake up several times during the night,I wake up a lot sooner than I would like'
#  'Good,I wake up several times during the night'
#  'Good,I struggle to fall asleep,I wake up a lot sooner than I would like'
#  'I struggle to fall asleep,I wake up a lot sooner than I would like'
#  'Good,I wake up a lot sooner than I would like']
# 8
# Unique values in 'How many sugary drinks do you consume per day?': [1 3 2 0 7 5 6 4]
# 5
# Unique values in 'Raw vegetables': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 5
# Unique values in 'Cow's milk': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 5
# Unique values in 'Fresh cheeses': ['Yes' 'Sometimes' 'NO' "Don't know" 'No']
# 27
# Unique values in 'Do you ever miss meals?': ['No' 'Yes' 'Yes, breakfast' 'Yes for craving' 'I have no time'
#  'Salto spesso i pasti perché non ho tempo' 'Yes lunch,I have no time'
#  'Yes lunch,Yes dinner,I have no time' 'Yes breakfast' 'Yes lunch'
#  'Yes breakfast,I have no time' 'Yes dinner' "No,I'm always hungry"
#  'Yes breakfast,Yes lunch' "I'm always hungry"
#  'Yes breakfast,Yes lunch,Yes dinner' 'Yes breakfast,Yes dinner'
#  'Yes breakfast,Yes lunch,I have no time'
#  "Yes breakfast,Yes lunch,I have no time,I'm always hungry"
#  "I have no time,I'm always hungry"
#  "Yes breakfast,I have no time,I'm always hungry"
#  'Yes breakfast,Yes dinner,I have no time' "Yes dinner,I'm always hungry"
#  'Yes lunch,Yes dinner' 'Yes dinner,I have no time'
#  "Yes breakfast,I'm always hungry"
#  "Yes breakfast,Yes lunch,Yes dinner,I have no time,I'm always hungry"]
# 5
# Unique values in 'Vegetable drinks (eg soy milk)': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 2
# Unique values in 'Do you eat fast?': ['No' 'Yes']
# 5
# Unique values in 'Cooked vegetables': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 5
# Unique values in 'Low-fat white yogurt': ['NO' 'Yes' 'Sometimes' "Don't know" 'No']
# 2
# Unique values in 'Do you ever eat distracted or not at the table?': ['No' 'Yes']
# 7
# Unique values in 'Do you wake up to eat at night?': ['Never' ' Often (>1/week)' ' Infrequent (1/month)' 'Every Day'
#  'Every day' 'Infrequent (1/month)' 'Often (>1/week)']
# 79
# Unique values in 'When are you hungry during the day?': ['Before Dinner' 'When I wake Up' 'In The Afternoon' 'After Dinner'
#  'During the morning' "I'm always hungry"
#  'During the morning,In the afternoon' 'After lunch'
#  'During the morning,Before lunch,Before Dinner'
#  'In the afternoon,Before Dinner' 'When I wake Up,After lunch'
#  'Before lunch,After Dinner'
#  "Before Dinner,After Dinner,I'm always hungry"
#  'When I wake Up,Before lunch,Before Dinner'
#  'In the afternoon,After Dinner' 'Before lunch,Before Dinner'
#  'During the morning,In the afternoon,Before Dinner'
#  'When I wake Up,During the morning,In the afternoon,Before lunch,Before Dinner'
#  'When I wake Up,Before Dinner' 'After lunch,Before Dinner'
#  'During the morning,Before Dinner' 'In the afternoon' 'Before lunch'
#  'When I wake Up,During the morning,Before lunch,Before Dinner'
#  'When I wake Up,In the afternoon,Before Dinner'
#  'During the morning,After Dinner' 'In the afternoon,Before lunch'
#  'In the afternoon,Before Dinner,After Dinner'
#  'When I wake Up,Before lunch'
#  'When I wake Up,During the morning,Before lunch'
#  'After lunch,Before Dinner,After Dinner'
#  'In the afternoon,Before lunch,Before Dinner,After Dinner'
#  'In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner'
#  'In the afternoon,Before lunch,After lunch,Before Dinner'
#  'In the afternoon,Before lunch,Before Dinner'
#  'In the afternoon,After lunch,After Dinner' 'When I wake Up,After Dinner'
#  "After lunch,I'm always hungry"
#  'During the morning,After lunch,Before Dinner'
#  'In the afternoon,After lunch'
#  "During the morning,Before lunch,I'm always hungry"
#  'During the morning,After lunch'
#  'Before lunch,Before Dinner,After Dinner'
#  'When I wake Up,During the morning,In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner'
#  'During the morning,In the afternoon,Before lunch,Before Dinner'
#  'When I wake Up,Before lunch,Before Dinner,After Dinner'
#  'After lunch,After Dinner' 'During the morning,Before lunch'
#  'When I wake Up,During the morning,Before Dinner'
#  "In the afternoon,Before lunch,Before Dinner,I'm always hungry"
#  'During the morning,Before Dinner,After Dinner'
#  'When I wake Up,During the morning'
#  "When I wake Up,In the afternoon,After lunch,After Dinner,I'm always hungry"
#  'When I wake Up,In the afternoon,Before lunch,Before Dinner'
#  'Before lunch,After lunch' "When I wake Up,I'm always hungry"
#  'In the afternoon,Before lunch,After Dinner'
#  'When I wake Up,During the morning,In the afternoon,Before Dinner'
#  'When I wake Up,During the morning,After lunch,Before Dinner'
#  "In the afternoon,I'm always hungry" 'Before Dinner,After Dinner'
#  "Before lunch,Before Dinner,After Dinner,I'm always hungry"
#  'When I wake Up,After lunch,Before Dinner'
#  'During the morning,In the afternoon,Before lunch'
#  'When I wake Up,During the morning,After Dinner'
#  'When I wake Up,Before lunch,After Dinner'
#  'During the morning,In the afternoon,After Dinner'
#  'During the morning,In the afternoon,After lunch,Before Dinner,After Dinner'
#  "Before lunch,Before Dinner,I'm always hungry"
#  "When I wake Up,Before lunch,Before Dinner,I'm always hungry"
#  "When I wake Up,During the morning,In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner,I'm always hungry"
#  "During the morning,In the afternoon,I'm always hungry"
#  "When I wake Up,During the morning,In the afternoon,Before lunch,Before Dinner,I'm always hungry"
#  "In the afternoon,Before Dinner,After Dinner,I'm always hungry"
#  'In the afternoon,After lunch,Before Dinner'
#  'Before lunch,After lunch,Before Dinner,After Dinner'
#  'During the morning,After lunch,After Dinner'
#  'During the morning,Before lunch,After Dinner'
#  'When I wake Up,After lunch,After Dinner']
# 7
# Unique values in 'How many times do you eat a day?': [5 6 3 4 7 2 1]
# 5
# Unique values in 'Nuts': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 5
# Unique values in 'Legumes': ['Yes' 'Sometimes' 'NO' "Don't know" 'No']
# 5
# Unique values in 'Fish': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 5
# Unique values in 'Fruits': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 5
# Unique values in 'Eggs': ['Yes' 'NO' 'Sometimes' "Don't know" 'No']
# 5
# Unique values in 'Whole grains food': ['Yes' 'Sometimes' 'NO' "Don't know" 'No']
# 7
# Unique values in 'Do you happen to eat uncontrollably even if you're not hungry?': [' Infrequent (1/month)' 'Never' 'Every Day' ' Often (>1/week)'
#  'Every day' 'Infrequent (1/month)' 'Often (>1/week)']
# 16
# Unique values in 'How many times do you consume alcoholic beverages in a week?': [1 3 5 7 2 0 4 6 '0' '1' '4' '3' '2' '5' '7+' '6']
# 5
# Unique values in 'Meat': ['Yes' 'Sometimes' "Don't know" 'NO' 'No']

# %% [markdown]
# ## Что нужно поменять?
# Объединить ответы в столбцах
# - 'Do you ever miss meals?
# - 'When are you hungry during the day?

# %% [markdown]
# ### Преобразование значений столбца 'When are you hungry during the day?

# %%
df['When are you hungry during the day?'].unique()
# Out:
# array(['Before Dinner', 'When I wake Up', 'In The Afternoon',
#        'After Dinner', 'During the morning', "I'm always hungry",
#        'During the morning,In the afternoon', 'After lunch',
#        'During the morning,Before lunch,Before Dinner',
#        'In the afternoon,Before Dinner', 'When I wake Up,After lunch',
#        'Before lunch,After Dinner',
#        "Before Dinner,After Dinner,I'm always hungry",
#        'When I wake Up,Before lunch,Before Dinner',
#        'In the afternoon,After Dinner', 'Before lunch,Before Dinner',
#        'During the morning,In the afternoon,Before Dinner',
#        'When I wake Up,During the morning,In the afternoon,Before lunch,Before Dinner',
#        'When I wake Up,Before Dinner', 'After lunch,Before Dinner',
#        'During the morning,Before Dinner', 'In the afternoon',
#        'Before lunch',
#        'When I wake Up,During the morning,Before lunch,Before Dinner',
#        'When I wake Up,In the afternoon,Before Dinner',
#        'During the morning,After Dinner', 'In the afternoon,Before lunch',
#        'In the afternoon,Before Dinner,After Dinner',
#        'When I wake Up,Before lunch',
#        'When I wake Up,During the morning,Before lunch',
#        'After lunch,Before Dinner,After Dinner',
#        'In the afternoon,Before lunch,Before Dinner,After Dinner',
#        'In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner',
#        'In the afternoon,Before lunch,After lunch,Before Dinner',
#        'In the afternoon,Before lunch,Before Dinner',
#        'In the afternoon,After lunch,After Dinner',
#        'When I wake Up,After Dinner', "After lunch,I'm always hungry",
#        'During the morning,After lunch,Before Dinner',
#        'In the afternoon,After lunch',
#        "During the morning,Before lunch,I'm always hungry",
#        'During the morning,After lunch',
#        'Before lunch,Before Dinner,After Dinner',
#        'When I wake Up,During the morning,In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner',
#        'During the morning,In the afternoon,Before lunch,Before Dinner',
#        'When I wake Up,Before lunch,Before Dinner,After Dinner',
#        'After lunch,After Dinner', 'During the morning,Before lunch',
#        'When I wake Up,During the morning,Before Dinner',
#        "In the afternoon,Before lunch,Before Dinner,I'm always hungry",
#        'During the morning,Before Dinner,After Dinner',
#        'When I wake Up,During the morning',
#        "When I wake Up,In the afternoon,After lunch,After Dinner,I'm always hungry",
#        'When I wake Up,In the afternoon,Before lunch,Before Dinner',
#        'Before lunch,After lunch', "When I wake Up,I'm always hungry",
#        'In the afternoon,Before lunch,After Dinner',
#        'When I wake Up,During the morning,In the afternoon,Before Dinner',
#        'When I wake Up,During the morning,After lunch,Before Dinner',
#        "In the afternoon,I'm always hungry", 'Before Dinner,After Dinner',
#        "Before lunch,Before Dinner,After Dinner,I'm always hungry",
#        'When I wake Up,After lunch,Before Dinner',
#        'During the morning,In the afternoon,Before lunch',
#        'When I wake Up,During the morning,After Dinner',
#        'When I wake Up,Before lunch,After Dinner',
#        'During the morning,In the afternoon,After Dinner',
#        'During the morning,In the afternoon,After lunch,Before Dinner,After Dinner',
#        "Before lunch,Before Dinner,I'm always hungry",
#        "When I wake Up,Before lunch,Before Dinner,I'm always hungry",
#        "When I wake Up,During the morning,In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner,I'm always hungry",
#        "During the morning,In the afternoon,I'm always hungry",
#        "When I wake Up,During the morning,In the afternoon,Before lunch,Before Dinner,I'm always hungry",
#        "In the afternoon,Before Dinner,After Dinner,I'm always hungry",
#        'In the afternoon,After lunch,Before Dinner',
#        'Before lunch,After lunch,Before Dinner,After Dinner',
#        'During the morning,After lunch,After Dinner',
#        'During the morning,Before lunch,After Dinner',
#        'When I wake Up,After lunch,After Dinner'], dtype=object)

# %%
len(df['When are you hungry during the day?'].unique())
# Out:
# 79

# %% [markdown]
# ***Финальные уникальные значения***
# 1. Утром - in the morning
# 2. Во второй половине дня - in the afternoon
# 3. Вечером - in the evening
# 4. В первой и второй половине дня - morning+afternoon
# 5. Во второй и третьей - afternoon+evening
# 6. В третьей и первой - morning+evening
# 7. Я всегда голоден  - I am always hungry

# %%
df['When are you hungry during the day?'] = df['When are you hungry during the day?'].replace(['When I wake Up,During the morning', 'When I wake Up', 'During the morning'], 'In the morning')
df['When are you hungry during the day?'] = df['When are you hungry during the day?'].replace(['After lunch', 'Before lunch,After lunch', 'In The Afternoon', 'In the afternoon,After lunch', 'In the afternoon,Before lunch', 'In the afternoon', 'Before lunch'], 'In the afternoon')
df['When are you hungry during the day?'] = df['When are you hungry during the day?'].replace(['Before Dinner,After Dinner', 'Before Dinner', 'After Dinner'], 'In the evening')
df['When are you hungry during the day?'] = df['When are you hungry during the day?'].replace(['During the morning,In the afternoon', 'During the morning,In the afternoon,Before lunch', 'During the morning,Before lunch', 'During the morning,After lunch', 'When I wake Up,Before lunch', 'When I wake Up,During the morning,Before lunch', 'When I wake Up,After lunch'], 'morning+afternoon')
df['When are you hungry during the day?'] = df['When are you hungry during the day?'].replace(['Before lunch,After lunch,Before Dinner,After Dinner', 'In the afternoon,After lunch,Before Dinner', 'In the afternoon,Before lunch,After Dinner', 'After lunch,After Dinner', 'Before lunch,Before Dinner,After Dinner', 'In the afternoon,After lunch,After Dinner', 'In the afternoon,Before lunch,Before Dinner,After Dinner', 'In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner', 'In the afternoon,Before lunch,After lunch,Before Dinner', 'In the afternoon,Before lunch,Before Dinner', 'After lunch,Before Dinner,After Dinner', 'In the afternoon,Before Dinner,After Dinner', 'After lunch,Before Dinner', 'In the afternoon,After Dinner', 'Before lunch,Before Dinner', 'Before lunch,After Dinner', 'In the afternoon,Before Dinner'], 'afternoon+evening')
df['When are you hungry during the day?'] = df['When are you hungry during the day?'].replace([ 'When I wake Up,During the morning,After Dinner','During the morning,Before Dinner,After Dinner' ,'When I wake Up,During the morning,Before Dinner','When I wake Up,After Dinner','During the morning,After Dinner', 'During the morning,Before Dinner', 'When I wake Up,Before Dinner'],'morning+evening')
len(df['When are you hungry during the day?'].unique())
# Out:
# 41

# %%
 df['When are you hungry during the day?'] = df['When are you hungry during the day?'].replace(['During the morning,Before lunch,Before Dinner',
    'During the morning,In the afternoon,Before Dinner',
   'When I wake Up,During the morning,In the afternoon,Before lunch,Before Dinner',
   'When I wake Up,During the morning,In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner',
    "During the morning,Before lunch,I'm always hungry",
   'During the morning,In the afternoon,Before lunch,Before Dinner',
     'When I wake Up,Before lunch,Before Dinner,After Dinner',
   "I'm always hungry",
       'During the morning,After lunch,After Dinner',
   "In the afternoon,Before lunch,Before Dinner,I'm always hungry",
       'During the morning,Before lunch,After Dinner',
       'When I wake Up,After lunch,After Dinner',
       "In the afternoon,Before Dinner,After Dinner,I'm always hungry",
       "When I wake Up,During the morning,In the afternoon,Before lunch,Before Dinner,I'm always hungry",
       "During the morning,In the afternoon,I'm always hungry",
 "After lunch,I'm always hungry",
       'During the morning,After lunch,Before Dinner',
       "Before lunch,Before Dinner,I'm always hungry",
       "When I wake Up,Before lunch,Before Dinner,I'm always hungry",
       "When I wake Up,During the morning,In the afternoon,Before lunch,After lunch,Before Dinner,After Dinner,I'm always hungry",
       'When I wake Up,Before lunch,After Dinner',
       'During the morning,In the afternoon,After Dinner',
       'During the morning,In the afternoon,After lunch,Before Dinner,After Dinner',
       'When I wake Up,After lunch,Before Dinner',
     "Before lunch,Before Dinner,After Dinner,I'm always hungry",
    "In the afternoon,I'm always hungry",
  'When I wake Up,During the morning,In the afternoon,Before Dinner',
       'When I wake Up,During the morning,After lunch,Before Dinner',
     "When I wake Up,I'm always hungry",
  "When I wake Up,In the afternoon,After lunch,After Dinner,I'm always hungry",
       'When I wake Up,In the afternoon,Before lunch,Before Dinner',
  'When I wake Up,During the morning,Before lunch,Before Dinner',
       'When I wake Up,In the afternoon,Before Dinner',
  "Before Dinner,After Dinner,I'm always hungry",
       'When I wake Up,Before lunch,Before Dinner'], "I'm always hungry")
len(df['When are you hungry during the day?'].unique())
# Out:
# 7

# %%
df['When are you hungry during the day?'].unique()
# Out:
# array(['In the evening', 'In the morning', 'In the afternoon',
#        "I'm always hungry", 'morning+afternoon', 'afternoon+evening',
#        'morning+evening'], dtype=object)

# %%
#df.to_csv('df.csv', index=False) 
#сохранение для дальнейшего использования
